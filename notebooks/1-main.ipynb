# %% [markdown]
# # The very first Python notebook - main.ipynb

# %% [markdown]
# ## Hello world - printing on the console
# The `print()` built-in function and the `+` operator.

# %%
print('Paul McCartney')
# Out:
# Paul McCartney

# %%
print('Paul McCartney', 'was born in', 1942)
# Out:
# Paul McCartney was born in 1942

# %%
help('print')
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
# print('Paul McCartney', 'was born in', 1942 + '.')
print('Paul McCartney', 'was born in', str(1942) + '.')

# %%
print('Paul McCartney wrote \'Yesterday\' in \n' + str(1965) + '.')

# %% [markdown]
# ## Reading from the keyboard
# The `input()` built-in function.

# %%
print('Paul McCartney was born in: ')
year = input()
print('Paul McCartney was born in:', year + '.')
# Out:
# Paul McCartney was born in:
#  1942
# Paul McCartney was born in: 1942.

# %%
print('Paul McCartney was born in: ', end='end', sep = 'qqq')
year = input()
print('Paul McCartney was born in:', year + '.', sep = 'qqq')
# Out:
# Paul McCartney was born in: end
#  1942
# Paul McCartney was born in:qqq1942.

# %%
print('Paul McCartney was born in:', str(int(input())) + '.')
# Out:
#  1942
# Paul McCartney was born in: 1942.

# %% [markdown]
# ## User-defined functions
# A simple function and function call.

# %%
def year_of_birth():
    """A definition
    """
    print('Paul McCartney was born in: ', end='')
    year = input()
    return year

# %%
print(year_of_birth.__doc__)
# Out:
# A definition

# %% [markdown]
# ## Loops
# Simple `for` and `while` loops and the `range()` built-in function.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Lists
# A simple list, accessing list elements, printing lists.

# %%
songs = ['Oh, Darling', 'The Long and Winding Road', 'She\'s a Woman']
print(songs[2])
print(songs)
# Out:
# She's a Woman
# ['Oh, Darling', 'The Long and Winding Road', "She's a Woman"]

# %%
print('; '.join(songs) + '.')
# Out:
# Oh, Darling; The Long and Winding Road; She's a Woman.

# %% [markdown]
# ## Looping through list elements
# Using `for` loops and the `enumerate()` built-in function.

# %%
for i in range(len(songs)):
    print(songs[i], len(songs[i]))
# Out:
# Oh, Darling 11
# The Long and Winding Road 25
# She's a Woman 13

# %%
for i, song in enumerate(songs):
    print(str(i + 1) + ':', song)
# Out:
# 1: Oh, Darling
# 2: The Long and Winding Road
# 3: She's a Woman

# %%
print(enumerate(songs))
# Out:
# <enumerate object at 0x000001EDC05217C0>

# %%
print(enumerate(songs))

# %%
print(list(enumerate(songs)))
# Out:
# [(0, 'Oh, Darling'), (1, 'The Long and Winding Road'), (2, "She's a Woman")]

# %%
print(list(enumerate(songs, start=1)))

# %%
for i, song in enumerate(songs, start=1):
    print(str(i) + ':', song)

# %% [markdown]
# ## Global variables
# `__name__`, `__file__`, `__doc__`, ..., and the `globals()` built-in function.

# %%
print(__name__)
# Out:
# __main__

# %% [markdown]
# `__file__` can be directly printed from Python scripts, but not from Jupyter notebooks.

# %%
# print(__file__)   # Doesn't work from a notebook and from a .py generated from a notebook, just from an original .py

# %% [markdown]
# Printing doc strings and all global variables.

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', "print('Paul McCartney')", "print('Paul McCartney', 'was born in', 1942)", "help('print')", "print('Paul McCartney was born in: ')\nyear = input()\nprint('Paul McCartney was born in:', year + '.')", "print('Paul McCartney was born in:', str(int(input())) + '.')", "print('Paul McCartney was born in: ', end='end')\nyear = input()\nprint('Paul McCartney was born in:', year + '.')", "print('Paul McCartney was born in: ', end='end', sep = 'qqq')\nyear = input()\nprint('Paul McCartney was born in:', year + '.')", "print('Paul McCartney was born in: ', end='end', sep = 'qqq')\nyear = input()\nprint('Paul McCartney was born in:', year + '.', sep = 'qqq')", "print('Paul McCartney was born in: ', end='end', sep = 'qqq')\nyear = input()\nprint('Paul McCartney was born in:', year + '.', sep = 'qqq)", "print('Paul McCartney was born in: ', end='end', sep = 'qqq')\nyear = input()\nprint('Paul McCartney was born in:', year + '.', sep = 'qqq')", "def year_of_birth():\n    print('Paul McCartney was born in: ', end='')\n    year = input()\n    return year", "print(year_of_birth() + '.')", 'for i in range(5):\n    print(i)', 'i = 0\nwhile i < 5:\n    print(i)\n    i += 1', "songs = ['Oh, Darling', 'The Long and Winding Road', 'She\\'s a Woman']\nprint(songs[2])\nprint(songs)", "print('; '.join(songs) + '.')", 'for i in range(len(songs)):\n    print(songs[i])', 'for i in range(len(songs)):\n    print(songs[i])\n    print(len(songs[i])', 'for i in range(len(songs)):\n    print(songs[i])\n    print(len(songs[i]))', 'for i in range(len(songs)):\n    print(songs[i], len(songs[i]))', "for i, song in enumerate(songs):\n    print(str(i + 1) + ':', song)", 'print(enumerate(songs))', 'print(list(enumerate(songs)))', 'print(__name__)', 'print(__doc__)\n# print(globals())', 'print(globals())'], '_oh': {}, '_dh': [WindowsPath('C:/Users/student2/Desktop/Py-notebooks')], 'In': ['', "print('Paul McCartney')", "print('Paul McCartney', 'was born in', 1942)", "help('print')", "print('Paul McCartney was born in: ')\nyear = input()\nprint('Paul McCartney was born in:', year + '.')", "print('Paul McCartney was born in:', str(int(input())) + '.')", "print('Paul McCartney was born in: ', end='end')\nyear = input()\nprint('Paul McCartney was born in:', year + '.')", "print('Paul McCartney was born in: ', end='end', sep = 'qqq')\nyear = input()\nprint('Paul McCartney was born in:', year + '.')", "print('Paul McCartney was born in: ', end='end', sep = 'qqq')\nyear = input()\nprint('Paul McCartney was born in:', year + '.', sep = 'qqq')", "print('Paul McCartney was born in: ', end='end', sep = 'qqq')\nyear = input()\nprint('Paul McCartney was born in:', year + '.', sep = 'qqq)", "print('Paul McCartney was born in: ', end='end', sep = 'qqq')\nyear = input()\nprint('Paul McCartney was born in:', year + '.', sep = 'qqq')", "def year_of_birth():\n    print('Paul McCartney was born in: ', end='')\n    year = input()\n    return year", "print(year_of_birth() + '.')", 'for i in range(5):\n    print(i)', 'i = 0\nwhile i < 5:\n    print(i)\n    i += 1', "songs = ['Oh, Darling', 'The Long and Winding Road', 'She\\'s a Woman']\nprint(songs[2])\nprint(songs)", "print('; '.join(songs) + '.')", 'for i in range(len(songs)):\n    print(songs[i])', 'for i in range(len(songs)):\n    print(songs[i])\n    print(len(songs[i])', 'for i in range(len(songs)):\n    print(songs[i])\n    print(len(songs[i]))', 'for i in range(len(songs)):\n    print(songs[i], len(songs[i]))', "for i, song in enumerate(songs):\n    print(str(i + 1) + ':', song)", 'print(enumerate(songs))', 'print(list(enumerate(songs)))', 'print(__name__)', 'print(__doc__)\n# print(globals())', 'print(globals())'], 'Out': {}, 'get_ipython': <bound method InteractiveShe ...

# %% [markdown]
# ## The *import* statement - importing from other modules
# Creating another module and importing a function from it.
#
# If the other module resides in the same directory as the notebook (or the `.py` file) that imports it, then the standard `from <another module> import func` is used (see [this](https://stackoverflow.com/a/53311583/1899061)). If the other module resides in another directory, the corresponding path must be appended before the `import`, as in the following example.

# %%
import sys
sys.path.append("python/")
from inception_clean import year_of_birth

# %%
print(year_of_birth())
# Out:
# Paul McCartney was born in:
#  1942
# 1942
